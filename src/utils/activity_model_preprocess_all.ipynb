# %%
import os
import pandas as pd
import numpy as np

# %%
motif_location_output_file = "/data5/deepro/starrseq/main_lib/results/activity_prediction/data/motif_odds.tsv"

# %% [markdown]
# # Need to parse the output file to be compatible with activity

# %% [markdown]
# ## Motif probability

# %%
motif_raw_df = pd.read_csv(motif_location_output_file, sep="\t")

# %%
motif_raw_df.head()
# Out:
#                  PositionID  Offset    Sequence  \
# 0  chrX:154800550-154801050     -93  ATGAGTAAGC
# 1  chrX:154800550-154801050     -85  GATGAGTAAG
# 2  chrX:154800500-154801000     -43  ATGAGTAAGC
# 3  chrX:154800500-154801000     -35  GATGAGTAAG
# 4  chrX:154800450-154800950       7  ATGAGTAAGC
#
#                                          Motif Name Strand  MotifScore
# 0  AP-1(bZIP)/ThioMac-PU.1-ChIP-Seq(GSE21512)/Homer      +    6.562859
# 1  AP-1(bZIP)/ThioMac-PU.1-ChIP-Seq(GSE21512)/Homer      -    6.561993
# 2  AP-1(bZIP)/ThioMac-PU.1-ChIP-Seq(GSE21512)/Homer      +    6.562859
# 3  AP-1(bZIP)/ThioMac-PU.1-ChIP-Seq(GSE21512)/Homer      -    6.561993
# 4  AP-1(bZIP)/ThioMac-PU.1-ChIP-Seq(GSE21512)/Homer      +    6.562859

# %%
def process(df_row):
    chrm = df_row[0].split(":")[0]
    start,end = df_row[0].split(":")[1].split("-")
    prob = np.exp(df_row[5])/(1 + np.exp(df_row[5]))
    return pd.Series({"chrm":chrm, "start":start, "end": end, "motif": df_row[3], "strand": df_row[4], "prob": prob})

# %%
motif_df_path = "/data5/deepro/starrseq/main_lib/results/activity_prediction/data/motif_df_tmp.tsv.gz"

# %%
# taking 246 minutes
if not os.path.exists(motif_df_path):
    motif_df = motif_raw_df.apply(process, axis=1)
    motif_df.to_pickle(motif_df_path)
else:
    motif_df = pd.read_pickle(motif_df_path)

# %%
motif_df.head()
# Out:
#    chrm      start        end  \
# 0  chrX  154800550  154801050
# 1  chrX  154800550  154801050
# 2  chrX  154800500  154801000
# 3  chrX  154800500  154801000
# 4  chrX  154800450  154800950
#
#                                               motif strand      prob
# 0  AP-1(bZIP)/ThioMac-PU.1-ChIP-Seq(GSE21512)/Homer      +  0.998590
# 1  AP-1(bZIP)/ThioMac-PU.1-ChIP-Seq(GSE21512)/Homer      -  0.998589
# 2  AP-1(bZIP)/ThioMac-PU.1-ChIP-Seq(GSE21512)/Homer      +  0.998590
# 3  AP-1(bZIP)/ThioMac-PU.1-ChIP-Seq(GSE21512)/Homer      -  0.998589
# 4  AP-1(bZIP)/ThioMac-PU.1-ChIP-Seq(GSE21512)/Homer      +  0.998590

# %%
motif_df_pivot = motif_df.pivot_table('prob', ["chrm", "start", "end"], ["motif", "strand"], fill_value=0.0)

# %%
motif_df_pivot
# Out:
# motif                    AMYB(HTH)/Testes-AMYB-ChIP-Seq(GSE44588)/Homer       \
# strand                                                                +    -
# chrm start     end
# chr1 100048200 100048700                                            0.0  0.0
#      100048250 100048750                                            0.0  0.0
#      100048300 100048800                                            0.0  0.0
#      100048350 100048850                                            0.0  0.0
#      100048400 100048900                                            0.0  0.0
# ...                                                                 ...  ...
# chrX 9341850   9342350                                              0.0  0.0
#      9341900   9342400                                              0.0  0.0
#      9341950   9342450                                              0.0  0.0
#      9342000   9342500                                              0.0  0.0
#      9342050   9342550                                              0.0  0.0
#
# motif                    AP-1(bZIP)/ThioMac-PU.1-ChIP-Seq(GSE21512)/Homer  \
# strand                                                                  +
# chrm start     end
# chr1 100048200 100048700                                              0.0
#      100048250 100048750                                              0.0
#      100048300 100048800                                              0.0
#      100048350 100048850                                              0.0
#      100048400 100048900                                              0.0
# ...                                                                   ...
# chrX 9341850   9342350                                                0.0
#      9341900   9342400                                                0.0
#      9341950   9342450                                                0.0
#      9342000   9342500                                                0.0
#      9342050   9342550                                                0.0
#
# motif                          \
# strand                      -
# chrm start     end
# chr1 100048200 100048700  0.0
#      100048250 100048750  0.0
#      100048300 100048800  0.0
#      100048350 100048850  0.0
#      100048400 100048900  0.0
# ...                       ...
# chrX 9341850   9342350    0.0
#      9341900   9342400    0.0
#      9341950   9342450    0.0
#      9342000   9342500    0.0
#      9342050   9342550    0.0
#
# motif                    AP-2alpha(AP2)/Hela-AP2alpha-ChIP-Seq(GSE31477)/Homer  \
# strand                                                                       +
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
# ...                                                                     ...
# chrX 9341850   9342350                                                  0.0
#      9341900   9342400                                                  0.0
#      9341950   9342450                                                  0.0
#      9342000   9342500                                                  0.0
#      9342050   9342550                                                  0.0
#
# motif                          \
# strand                      -
# chrm start     end
# chr1 100048200 100048700  0.0
#      100048250 100048750  0.0
#      100048300 100048800  0.0
#      100048350 100048850  0.0
#      100048400 100048900  0.0
# ...                       ...
# chrX 9341850   9342350    0.0
#      9341900   9342400    0.0
#      9341950   9342450    0.0
#      9342000   9342500    0.0
#      9342050   9342550    0.0
#
# motif                    AP-2gamma(AP2)/MCF7-TFAP2C-ChIP-Seq(GSE21234)/Homer  \
# strand                                                                     +
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
# ...                                                                     ...
# chrX 9341850   9342350                                                  0.0
#      9341900   9342400                                                  0.0
#      9341950   9342450                                                  0.0
#      9342000   9342500                                                  0.0
#      9342050   9342550                                                  0.0
#
# motif                          \
# strand                      -
# chrm start     end
# chr1 100048200 100048700  0.0
#      100048250 100048750  0.0
#      100048300 100048800  0.0
#      100048350 100048850  0.0
#      100048400 100048900  0.0
# ...                       ...
# chrX 9341850   9342350    0.0
#      9341900   9342400    0.0
#      9341950   9342450    0.0
#      9342000   9342500    0.0
#      9342050   9342550    0.0
#
# motif                    AR-halfsite(NR)/LNCaP-AR-ChIP-Seq(GSE27824)/Homer  \
# strand                                                                   +
# chrm start     end
# chr1 100048200 100048700                                               0.0
#      100048250 100048750                                               0.0
#      100048300 100048800                                               0.0
#      100048350 100048850                                               0.0
#      100048400 100048900                                               0.0
# ...                                                                    ...
# chrX 9341850   9342350                                                 0.0
#      9341900   9342400                                                 0.0
#      9341950   9342450                                                 0.0
#      9342000   9342500                                                 0.0
#      9342050   9342550                                                 0.0
#
# motif                              ...  \
# strand                          -  ...
# chrm start     end                 ...
# chr1 100048200 100048700  0.00000  ...
#      100048250 100048750  0.00000  ...
#      100048300 100048800  0.99945  ...
#      100048350 100048850  0.99945  ...
#      100048400 100048900  0.99945  ...
# ...                           ...  ...
# chrX 9341850   9342350    0.00000  ...
#      9341900   9342400    0.00000  ...
#      9341950   9342450    0.00000  ...
#      9342000   9342500    0.00000  ...
#      9342050   9342550    0.00000  ...
#
# motif                    n-Myc(bHLH)/mES-nMyc-ChIP-Seq(GSE11431)/Homer       \
# strand                                                               +    -
# chrm start     end
# chr1 100048200 100048700                                           0.0  0.0
#      100048250 100048750                                           0.0  0.0
#      100048300 100048800                                           0.0  0.0
#      100048350 100048850                                           0.0  0.0
#      100048400 100048900                                           0.0  0.0
# ...                                                                ...  ...
# chrX 9341850   9342350                                             0.0  0.0
#      9341900   9342400                                             0.0  0.0
#      9341950   9342450                                             0.0  0.0
#      9342000   9342500                                             0.0  0.0
#      9342050   9342550                                             0.0  0.0
#
# motif                    p53(p53)/Saos-p53-ChIP-Seq(GSE15780)/Homer       \
# strand                                                            +    -
# chrm start     end
# chr1 100048200 100048700                                        0.0  0.0
#      100048250 100048750                                        0.0  0.0
#      100048300 100048800                                        0.0  0.0
#      100048350 100048850                                        0.0  0.0
#      100048400 100048900                                        0.0  0.0
# ...                                                             ...  ...
# chrX 9341850   9342350                                          0.0  0.0
#      9341900   9342400                                          0.0  0.0
#      9341950   9342450                                          0.0  0.0
#      9342000   9342500                                          0.0  0.0
#      9342050   9342550                                          0.0  0.0
#
# motif                    p53(p53)/mES-cMyc-ChIP-Seq(GSE11431)/Homer       \
# strand                                                            +    -
# chrm start     end
# chr1 100048200 100048700                                        0.0  0.0
#      100048250 100048750                                        0.0  0.0
#      100048300 100048800                                        0.0  0.0
#      100048350 100048850                                        0.0  0.0
#      100048400 100048900                                        0.0  0.0
# ...                                                             ...  ...
# chrX 9341850   9342350                                          0.0  0.0
#      9341900   9342400                                          0.0  0.0
#      9341950   9342450                                          0.0  0.0
#      9342000   9342500                                          0.0  0.0
#      9342050   9342550                                          0.0  0.0
#
# motif                    p63(p53)/Keratinocyte-p63-ChIP-Seq(GSE17611)/Homer  \
# strand                                                                    +
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
# ...                                                                     ...
# chrX 9341850   9342350                                                  0.0
#      9341900   9342400                                                  0.0
#      9341950   9342450                                                  0.0
#      9342000   9342500                                                  0.0
#      9342050   9342550                                                  0.0
#
# motif                          \
# strand                      -
# chrm start     end
# chr1 100048200 100048700  0.0
#      100048250 100048750  0.0
#      100048300 100048800  0.0
#      100048350 100048850  0.0
#      100048400 100048900  0.0
# ...                       ...
# chrX 9341850   9342350    0.0
#      9341900   9342400    0.0
#      9341950   9342450    0.0
#      9342000   9342500    0.0
#      9342050   9342550    0.0
#
# motif                    p73(p53)/Trachea-p73-ChIP-Seq(PRJNA310161)/Homer
# strand                                                                  +    -
# chrm start     end
# chr1 100048200 100048700                                              0.0  0.0
#      100048250 100048750                                              0.0  0.0
#      100048300 100048800                                              0.0  0.0
#      100048350 100048850                                              0.0  0.0
#      100048400 100048900                                              0.0  0.0
# ...                                                                   ...  ...
# chrX 9341850   9342350                                                0.0  0.0
#      9341900   9342400                                                0.0  0.0
#      9341950   9342450                                                0.0  0.0
#      9342000   9342500                                                0.0  0.0
#      9342050   9342550                                                0.0  0.0
#
# [946694 rows x 872 columns]

# %% [markdown]
# ## Region wise activity

# %%
input_cov_bed = "/data5/deepro/starrseq/main_lib/results/activity_prediction/data/input.cov.bed"
cc_cov_bed = "/data5/deepro/starrseq/main_lib/results/activity_prediction/data/cc/cc.cov.bed"
ko_cov_bed = "/data5/deepro/starrseq/main_lib/results/activity_prediction/data/atf2/atf2.cov.bed"

# %%
df_in_cov = pd.read_csv(input_cov_bed, header=None, sep="\t")
df_cc_cov = pd.read_csv(cc_cov_bed, header=None, sep="\t")
df_ko_cov = pd.read_csv(ko_cov_bed, header=None, sep="\t")

# %%
df_cc_cov.loc[((df_cc_cov[0]=="chr17") & (df_cc_cov[1]==38510550) & (df_cc_cov[2]==38511050))]
# Out:
#             0         1         2                        3  4  5  6  7    8  \
# 364082  chr17  38510550  38511050  chr17:38510550-38511050  0  .  0  0  500
#
#           9
# 364082  0.0

# %%
# chr17	38510550	38511050
df_in_cov.loc[((df_in_cov[0]=="chr17") & (df_in_cov[1]==38510550) & (df_in_cov[2]==38511050))]
# Out:
#             0         1         2                        3  4  5  6  7    8  \
# 364082  chr17  38510550  38511050  chr17:38510550-38511050  0  .  0  0  500
#
#           9
# 364082  0.0

# %%
df_cc_act = df_cc_cov.iloc[:, [0,1,2]].astype(str).merge(df_cc_cov[6]/df_in_cov[6], left_index=True, right_index=True).set_index([0,1,2])
df_ko_act = df_cc_cov.iloc[:, [0,1,2]].astype(str).merge(df_ko_cov[6]/df_in_cov[6], left_index=True, right_index=True).set_index([0,1,2])

# %%
df_cc_act.rename(columns={6: "activity"}, inplace=True)
df_ko_act.rename(columns={6: "activity"}, inplace=True)

# %%
df_cc_act = df_cc_act.dropna()
df_ko_act = df_ko_act.dropna()

# %%
motif_df_pivot.columns = [f'{i}|{j}' if j != '' else f'{i}' for i,j in motif_df_pivot.columns]

# %%
motif_df_with_cc_act = motif_df_pivot.merge(df_cc_act, left_on=["chrm", "start", "end"], right_on=[0,1,2])
motif_df_with_ko_act = motif_df_pivot.merge(df_ko_act, left_on=["chrm", "start", "end"], right_on=[0,1,2])

# %%
motif_df_with_cc_act.head()
# Out:
#                           AMYB(HTH)/Testes-AMYB-ChIP-Seq(GSE44588)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                               0.0
#      100048250 100048750                                               0.0
#      100048300 100048800                                               0.0
#      100048350 100048850                                               0.0
#      100048400 100048900                                               0.0
#
#                           AMYB(HTH)/Testes-AMYB-ChIP-Seq(GSE44588)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                               0.0
#      100048250 100048750                                               0.0
#      100048300 100048800                                               0.0
#      100048350 100048850                                               0.0
#      100048400 100048900                                               0.0
#
#                           AP-1(bZIP)/ThioMac-PU.1-ChIP-Seq(GSE21512)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           AP-1(bZIP)/ThioMac-PU.1-ChIP-Seq(GSE21512)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           AP-2alpha(AP2)/Hela-AP2alpha-ChIP-Seq(GSE31477)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           AP-2alpha(AP2)/Hela-AP2alpha-ChIP-Seq(GSE31477)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           AP-2gamma(AP2)/MCF7-TFAP2C-ChIP-Seq(GSE21234)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           AP-2gamma(AP2)/MCF7-TFAP2C-ChIP-Seq(GSE21234)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           AR-halfsite(NR)/LNCaP-AR-ChIP-Seq(GSE27824)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           AR-halfsite(NR)/LNCaP-AR-ChIP-Seq(GSE27824)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                            0.00000
#      100048250 100048750                                            0.00000
#      100048300 100048800                                            0.99945
#      100048350 100048850                                            0.99945
#      100048400 100048900                                            0.99945
#
#                           ...  \
# chrm start     end        ...
# chr1 100048200 100048700  ...
#      100048250 100048750  ...
#      100048300 100048800  ...
#      100048350 100048850  ...
#      100048400 100048900  ...
#
#                           n-Myc(bHLH)/mES-nMyc-ChIP-Seq(GSE11431)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                              0.0
#      100048250 100048750                                              0.0
#      100048300 100048800                                              0.0
#      100048350 100048850                                              0.0
#      100048400 100048900                                              0.0
#
#                           p53(p53)/Saos-p53-ChIP-Seq(GSE15780)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                           0.0
#      100048250 100048750                                           0.0
#      100048300 100048800                                           0.0
#      100048350 100048850                                           0.0
#      100048400 100048900                                           0.0
#
#                           p53(p53)/Saos-p53-ChIP-Seq(GSE15780)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                           0.0
#      100048250 100048750                                           0.0
#      100048300 100048800                                           0.0
#      100048350 100048850                                           0.0
#      100048400 100048900                                           0.0
#
#                           p53(p53)/mES-cMyc-ChIP-Seq(GSE11431)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                           0.0
#      100048250 100048750                                           0.0
#      100048300 100048800                                           0.0
#      100048350 100048850                                           0.0
#      100048400 100048900                                           0.0
#
#                           p53(p53)/mES-cMyc-ChIP-Seq(GSE11431)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                           0.0
#      100048250 100048750                                           0.0
#      100048300 100048800                                           0.0
#      100048350 100048850                                           0.0
#      100048400 100048900                                           0.0
#
#                           p63(p53)/Keratinocyte-p63-ChIP-Seq(GSE17611)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           p63(p53)/Keratinocyte-p63-ChIP-Seq(GSE17611)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           p73(p53)/Trachea-p73-ChIP-Seq(PRJNA310161)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           p73(p53)/Trachea-p73-ChIP-Seq(PRJNA310161)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           activity
# chrm start     end
# chr1 100048200 100048700  0.547170
#      100048250 100048750  0.696721
#      100048300 100048800  0.786378
#      100048350 100048850  0.750000
#      100048400 100048900  0.698876
#
# [5 rows x 873 columns]

# %%
motif_df_with_ko_act.head()
# Out:
#                           AMYB(HTH)/Testes-AMYB-ChIP-Seq(GSE44588)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                               0.0
#      100048250 100048750                                               0.0
#      100048300 100048800                                               0.0
#      100048350 100048850                                               0.0
#      100048400 100048900                                               0.0
#
#                           AMYB(HTH)/Testes-AMYB-ChIP-Seq(GSE44588)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                               0.0
#      100048250 100048750                                               0.0
#      100048300 100048800                                               0.0
#      100048350 100048850                                               0.0
#      100048400 100048900                                               0.0
#
#                           AP-1(bZIP)/ThioMac-PU.1-ChIP-Seq(GSE21512)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           AP-1(bZIP)/ThioMac-PU.1-ChIP-Seq(GSE21512)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           AP-2alpha(AP2)/Hela-AP2alpha-ChIP-Seq(GSE31477)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           AP-2alpha(AP2)/Hela-AP2alpha-ChIP-Seq(GSE31477)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           AP-2gamma(AP2)/MCF7-TFAP2C-ChIP-Seq(GSE21234)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           AP-2gamma(AP2)/MCF7-TFAP2C-ChIP-Seq(GSE21234)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           AR-halfsite(NR)/LNCaP-AR-ChIP-Seq(GSE27824)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           AR-halfsite(NR)/LNCaP-AR-ChIP-Seq(GSE27824)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                            0.00000
#      100048250 100048750                                            0.00000
#      100048300 100048800                                            0.99945
#      100048350 100048850                                            0.99945
#      100048400 100048900                                            0.99945
#
#                           ...  \
# chrm start     end        ...
# chr1 100048200 100048700  ...
#      100048250 100048750  ...
#      100048300 100048800  ...
#      100048350 100048850  ...
#      100048400 100048900  ...
#
#                           n-Myc(bHLH)/mES-nMyc-ChIP-Seq(GSE11431)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                              0.0
#      100048250 100048750                                              0.0
#      100048300 100048800                                              0.0
#      100048350 100048850                                              0.0
#      100048400 100048900                                              0.0
#
#                           p53(p53)/Saos-p53-ChIP-Seq(GSE15780)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                           0.0
#      100048250 100048750                                           0.0
#      100048300 100048800                                           0.0
#      100048350 100048850                                           0.0
#      100048400 100048900                                           0.0
#
#                           p53(p53)/Saos-p53-ChIP-Seq(GSE15780)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                           0.0
#      100048250 100048750                                           0.0
#      100048300 100048800                                           0.0
#      100048350 100048850                                           0.0
#      100048400 100048900                                           0.0
#
#                           p53(p53)/mES-cMyc-ChIP-Seq(GSE11431)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                           0.0
#      100048250 100048750                                           0.0
#      100048300 100048800                                           0.0
#      100048350 100048850                                           0.0
#      100048400 100048900                                           0.0
#
#                           p53(p53)/mES-cMyc-ChIP-Seq(GSE11431)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                           0.0
#      100048250 100048750                                           0.0
#      100048300 100048800                                           0.0
#      100048350 100048850                                           0.0
#      100048400 100048900                                           0.0
#
#                           p63(p53)/Keratinocyte-p63-ChIP-Seq(GSE17611)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           p63(p53)/Keratinocyte-p63-ChIP-Seq(GSE17611)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           p73(p53)/Trachea-p73-ChIP-Seq(PRJNA310161)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           p73(p53)/Trachea-p73-ChIP-Seq(PRJNA310161)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           activity
# chrm start     end
# chr1 100048200 100048700  0.471698
#      100048250 100048750  0.520492
#      100048300 100048800  0.597523
#      100048350 100048850  0.609694
#      100048400 100048900  0.604494
#
# [5 rows x 873 columns]

# %% [markdown]
# ## Motif wise concentration

# %%
## Creating a motif metadata for concentration
import json
motif_metadata_file = "/afs/bx.psu.edu/user/d/dzb5732/work/girirajan_lab/starrseq/data/metadata_motif.json"

motif_meta_dict = {m:"" for m in motif_df["motif"].unique()}

if not os.path.exists(motif_metadata_file):
    with open(motif_metadata_file, "w") as f:  
        json.dump(motif_meta_dict, f, indent=4)

else:
    with open(motif_metadata_file, "r") as f:
        motif_meta_dict = json.load(f)

# %%
# TODO: add concentration from all KO lines
atf2_conc = "/data5/deepro/starrseq/rnaseq/count/rep3/ATF2_R3_S6_R1_001_normalized_lognormalized.tsv"
cc_conc = "/data5/deepro/starrseq/rnaseq/count/rep3/CC_R3_S24_R1_001_normalized_lognormalized.tsv"

# %%
atf2_conc_df = pd.read_csv(atf2_conc, sep="\t", header=None, index_col=0)
cc_conc_df = pd.read_csv(cc_conc, sep="\t", header=None, index_col=0)

# %%
ratf2conc_df = atf2_conc_df.loc[[m for m in set(motif_meta_dict.values()) if m]]
rccconc_df = cc_conc_df.loc[[m for m in set(motif_meta_dict.values()) if m]]

# %%
conc_df = rccconc_df.merge(ratf2conc_df, left_index=True, right_index=True)

# %%
ncdf = conc_df.divide(conc_df.max(axis=1), axis=0).fillna(0.0)

# %%
ncdf.columns = [c.split("_")[1] for c in ncdf.columns]

# %%
motif_conc_df = ncdf.groupby(by= ncdf.columns, axis=1).agg("mean")

# %% [markdown]
# # Rebuilding final dataframe as a training set

# %% [markdown]
# Final table format
#
# chrm | start | end | motif1+ | motif1- | motif1conc_cc | motif2+ | motif2- | motif2conc_cc | ... | cc_activity
#
# .
# .
# .
#
# chrm | start | end | motif1+ | motif1- | motif1conc_ko | motif2+ | motif2- | motif2conc_ko | ... | ko_activity

# %%
keep_columns = [k+ f"|{s}" for s in ("+", "-") for k,v in motif_meta_dict.items() if v]
keep_columns += ["activity"]

# %%
motif_df_with_cc_act = motif_df_with_cc_act.loc[:, keep_columns]
motif_df_with_ko_act = motif_df_with_ko_act.loc[:, keep_columns]

# %%
new_cols = [k+ "|conc" for k,v in motif_meta_dict.items() if v]

# %%
motif_conc_df.loc[motif_meta_dict[new_cols[0].replace("|conc", "")], "x"]
# Out:
# 0.8889495161404644

# %%
for col in new_cols:
    motif_df_with_cc_act[col] = motif_conc_df.loc[motif_meta_dict[col.replace("|conc", "")], "x"]
    motif_df_with_ko_act[col] = motif_conc_df.loc[motif_meta_dict[col.replace("|conc", "")], "y"]
# Out:
# /tmp/ipykernel_65939/1573620066.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   motif_df_with_cc_act[col] = motif_conc_df.loc[motif_meta_dict[col.replace("|conc", "")], "x"]
# /tmp/ipykernel_65939/1573620066.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   motif_df_with_ko_act[col] = motif_conc_df.loc[motif_meta_dict[col.replace("|conc", "")], "y"]

# %%
final_activity_df = pd.concat((motif_df_with_cc_act, motif_df_with_ko_act), axis=0)

# %%
final_activity_df
# Out:
#                           AP-2gamma(AP2)/MCF7-TFAP2C-ChIP-Seq(GSE21234)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
# ...                                                                     ...
# chrX 9341850   9342350                                                  0.0
#      9341900   9342400                                                  0.0
#      9341950   9342450                                                  0.0
#      9342000   9342500                                                  0.0
#      9342050   9342550                                                  0.0
#
#                           Ap4(bHLH)/AML-Tfap4-ChIP-Seq(GSE45738)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                             0.0
#      100048250 100048750                                             0.0
#      100048300 100048800                                             0.0
#      100048350 100048850                                             0.0
#      100048400 100048900                                             0.0
# ...                                                                  ...
# chrX 9341850   9342350                                               0.0
#      9341900   9342400                                               0.0
#      9341950   9342450                                               0.0
#      9342000   9342500                                               0.0
#      9342050   9342550                                               0.0
#
#                           FOXA1:AR(Forkhead,NR)/LNCAP-AR-ChIP-Seq(GSE27824)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
# ...                                                                     ...
# chrX 9341850   9342350                                                  0.0
#      9341900   9342400                                                  0.0
#      9341950   9342450                                                  0.0
#      9342000   9342500                                                  0.0
#      9342050   9342550                                                  0.0
#
#                           Arnt:Ahr(bHLH)/MCF7-Arnt-ChIP-Seq(Lo_et_al.)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
# ...                                                                     ...
# chrX 9341850   9342350                                                  0.0
#      9341900   9342400                                                  0.0
#      9341950   9342450                                                  0.0
#      9342000   9342500                                                  0.0
#      9342050   9342550                                                  0.0
#
#                           Ascl1(bHLH)/NeuralTubes-Ascl1-ChIP-Seq(GSE55840)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
# ...                                                                     ...
# chrX 9341850   9342350                                                  0.0
#      9341900   9342400                                                  0.0
#      9341950   9342450                                                  0.0
#      9342000   9342500                                                  0.0
#      9342050   9342550                                                  0.0
#
#                           Ascl2(bHLH)/ESC-Ascl2-ChIP-Seq(GSE97712)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                               0.0
#      100048250 100048750                                               0.0
#      100048300 100048800                                               0.0
#      100048350 100048850                                               0.0
#      100048400 100048900                                               0.0
# ...                                                                    ...
# chrX 9341850   9342350                                                 0.0
#      9341900   9342400                                                 0.0
#      9341950   9342450                                                 0.0
#      9342000   9342500                                                 0.0
#      9342050   9342550                                                 0.0
#
#                           Atf1(bZIP)/K562-ATF1-ChIP-Seq(GSE31477)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                              0.0
#      100048250 100048750                                              0.0
#      100048300 100048800                                              0.0
#      100048350 100048850                                              0.0
#      100048400 100048900                                              0.0
# ...                                                                   ...
# chrX 9341850   9342350                                                0.0
#      9341900   9342400                                                0.0
#      9341950   9342450                                                0.0
#      9342000   9342500                                                0.0
#      9342050   9342550                                                0.0
#
#                           Atf2(bZIP)/3T3L1-Atf2-ChIP-Seq(GSE56872)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                               0.0
#      100048250 100048750                                               0.0
#      100048300 100048800                                               0.0
#      100048350 100048850                                               0.0
#      100048400 100048900                                               0.0
# ...                                                                    ...
# chrX 9341850   9342350                                                 0.0
#      9341900   9342400                                                 0.0
#      9341950   9342450                                                 0.0
#      9342000   9342500                                                 0.0
#      9342050   9342550                                                 0.0
#
#                           Atf3(bZIP)/GBM-ATF3-ChIP-Seq(GSE33912)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                             0.0
#      100048250 100048750                                             0.0
#      100048300 100048800                                             0.0
#      100048350 100048850                                             0.0
#      100048400 100048900                                             0.0
# ...                                                                  ...
# chrX 9341850   9342350                                               0.0
#      9341900   9342400                                               0.0
#      9341950   9342450                                               0.0
#      9342000   9342500                                               0.0
#      9342050   9342550                                               0.0
#
#                           Atf4(bZIP)/MEF-Atf4-ChIP-Seq(GSE35681)/Homer|+  ...  \
# chrm start     end                                                        ...
# chr1 100048200 100048700                                             0.0  ...
#      100048250 100048750                                             0.0  ...
#      100048300 100048800                                             0.0  ...
#      100048350 100048850                                             0.0  ...
#      100048400 100048900                                             0.0  ...
# ...                                                                  ...  ...
# chrX 9341850   9342350                                               0.0  ...
#      9341900   9342400                                               0.0  ...
#      9341950   9342450                                               0.0  ...
#      9342000   9342500                                               0.0  ...
#      9342050   9342550                                               0.0  ...
#
#                           ZNF519(Zf)/HEK293-ZNF519.GFP-ChIP-Seq(GSE58341)/Homer|conc  \
# chrm start     end
# chr1 100048200 100048700                                           0.630057
#      100048250 100048750                                           0.630057
#      100048300 100048800                                           0.630057
#      100048350 100048850                                           0.630057
#      100048400 100048900                                           0.630057
# ...                                                                     ...
# chrX 9341850   9342350                                             0.850625
#      9341900   9342400                                             0.850625
#      9341950   9342450                                             0.850625
#      9342000   9342500                                             0.850625
#      9342050   9342550                                             0.850625
#
#                           ZNF528(Zf)/HEK293-ZNF528.GFP-ChIP-Seq(GSE58341)/Homer|conc  \
# chrm start     end
# chr1 100048200 100048700                                           0.024305
#      100048250 100048750                                           0.024305
#      100048300 100048800                                           0.024305
#      100048350 100048850                                           0.024305
#      100048400 100048900                                           0.024305
# ...                                                                     ...
# chrX 9341850   9342350                                             0.890435
#      9341900   9342400                                             0.890435
#      9341950   9342450                                             0.890435
#      9342000   9342500                                             0.890435
#      9342050   9342550                                             0.890435
#
#                           ZNF652/HepG2-ZNF652.Flag-ChIP-Seq(Encode)/Homer|conc  \
# chrm start     end
# chr1 100048200 100048700                                           0.652352
#      100048250 100048750                                           0.652352
#      100048300 100048800                                           0.652352
#      100048350 100048850                                           0.652352
#      100048400 100048900                                           0.652352
# ...                                                                     ...
# chrX 9341850   9342350                                             0.974039
#      9341900   9342400                                             0.974039
#      9341950   9342450                                             0.974039
#      9342000   9342500                                             0.974039
#      9342050   9342550                                             0.974039
#
#                           ZNF669(Zf)/HEK293-ZNF669.GFP-ChIP-Seq(GSE58341)/Homer|conc  \
# chrm start     end
# chr1 100048200 100048700                                           0.921915
#      100048250 100048750                                           0.921915
#      100048300 100048800                                           0.921915
#      100048350 100048850                                           0.921915
#      100048400 100048900                                           0.921915
# ...                                                                     ...
# chrX 9341850   9342350                                             0.592056
#      9341900   9342400                                             0.592056
#      9341950   9342450                                             0.592056
#      9342000   9342500                                             0.592056
#      9342050   9342550                                             0.592056
#
#                           ZNF675(Zf)/HEK293-ZNF675.GFP-ChIP-Seq(GSE58341)/Homer|conc  \
# chrm start     end
# chr1 100048200 100048700                                           0.337694
#      100048250 100048750                                           0.337694
#      100048300 100048800                                           0.337694
#      100048350 100048850                                           0.337694
#      100048400 100048900                                           0.337694
# ...                                                                     ...
# chrX 9341850   9342350                                             0.867670
#      9341900   9342400                                             0.867670
#      9341950   9342450                                             0.867670
#      9342000   9342500                                             0.867670
#      9342050   9342550                                             0.867670
#
#                           ZNF692(Zf)/HEK293-ZNF692.GFP-ChIP-Seq(GSE58341)/Homer|conc  \
# chrm start     end
# chr1 100048200 100048700                                           0.923242
#      100048250 100048750                                           0.923242
#      100048300 100048800                                           0.923242
#      100048350 100048850                                           0.923242
#      100048400 100048900                                           0.923242
# ...                                                                     ...
# chrX 9341850   9342350                                             0.439885
#      9341900   9342400                                             0.439885
#      9341950   9342450                                             0.439885
#      9342000   9342500                                             0.439885
#      9342050   9342550                                             0.439885
#
#                           ZNF711(Zf)/SHSY5Y-ZNF711-ChIP-Seq(GSE20673)/Homer|conc  \
# chrm start     end
# chr1 100048200 100048700                                           0.067274
#      100048250 100048750                                           0.067274
#      100048300 100048800                                           0.067274
#      100048350 100048850                                           0.067274
#      100048400 100048900                                           0.067274
# ...                                                                     ...
# chrX 9341850   9342350                                             0.922270
#      9341900   9342400                                             0.922270
#      9341950   9342450                                             0.922270
#      9342000   9342500                                             0.922270
#      9342050   9342550                                             0.922270
#
#                           ZNF768(Zf)/Rajj-ZNF768-ChIP-Seq(GSE111879)/Homer|conc  \
# chrm start     end
# chr1 100048200 100048700                                           0.965006
#      100048250 100048750                                           0.965006
#      100048300 100048800                                           0.965006
#      100048350 100048850                                           0.965006
#      100048400 100048900                                           0.965006
# ...                                                                     ...
# chrX 9341850   9342350                                             0.414931
#      9341900   9342400                                             0.414931
#      9341950   9342450                                             0.414931
#      9342000   9342500                                             0.414931
#      9342050   9342550                                             0.414931
#
#                           ZNF7(Zf)/HepG2-ZNF7.Flag-ChIP-Seq(Encode)/Homer|conc  \
# chrm start     end
# chr1 100048200 100048700                                           0.728655
#      100048250 100048750                                           0.728655
#      100048300 100048800                                           0.728655
#      100048350 100048850                                           0.728655
#      100048400 100048900                                           0.728655
# ...                                                                     ...
# chrX 9341850   9342350                                             0.925236
#      9341900   9342400                                             0.925236
#      9341950   9342450                                             0.925236
#      9342000   9342500                                             0.925236
#      9342050   9342550                                             0.925236
#
#                           ZSCAN22(Zf)/HEK293-ZSCAN22.GFP-ChIP-Seq(GSE58341)/Homer|conc
# chrm start     end
# chr1 100048200 100048700                                           0.745794
#      100048250 100048750                                           0.745794
#      100048300 100048800                                           0.745794
#      100048350 100048850                                           0.745794
#      100048400 100048900                                           0.745794
# ...                                                                     ...
# chrX 9341850   9342350                                             0.912235
#      9341900   9342400                                             0.912235
#      9341950   9342450                                             0.912235
#      9342000   9342500                                             0.912235
#      9342050   9342550                                             0.912235
#
# [1893193 rows x 1042 columns]

# %%
cols_together = [k + suf for k,v in motif_meta_dict.items() if v for suf in ("|+", "|-", "|conc")]
cols_together += ["activity"]

# %%
len(cols_together)
# Out:
# 1042

# %%
final_activity_df = final_activity_df.loc[:, cols_together]

# %%
final_activity_df.head()
# Out:
#                           AP-2gamma(AP2)/MCF7-TFAP2C-ChIP-Seq(GSE21234)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           AP-2gamma(AP2)/MCF7-TFAP2C-ChIP-Seq(GSE21234)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           AP-2gamma(AP2)/MCF7-TFAP2C-ChIP-Seq(GSE21234)/Homer|conc  \
# chrm start     end
# chr1 100048200 100048700                                            0.88895
#      100048250 100048750                                            0.88895
#      100048300 100048800                                            0.88895
#      100048350 100048850                                            0.88895
#      100048400 100048900                                            0.88895
#
#                           Ap4(bHLH)/AML-Tfap4-ChIP-Seq(GSE45738)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                             0.0
#      100048250 100048750                                             0.0
#      100048300 100048800                                             0.0
#      100048350 100048850                                             0.0
#      100048400 100048900                                             0.0
#
#                           Ap4(bHLH)/AML-Tfap4-ChIP-Seq(GSE45738)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                             0.0
#      100048250 100048750                                             0.0
#      100048300 100048800                                             0.0
#      100048350 100048850                                             0.0
#      100048400 100048900                                             0.0
#
#                           Ap4(bHLH)/AML-Tfap4-ChIP-Seq(GSE45738)/Homer|conc  \
# chrm start     end
# chr1 100048200 100048700                                           0.989811
#      100048250 100048750                                           0.989811
#      100048300 100048800                                           0.989811
#      100048350 100048850                                           0.989811
#      100048400 100048900                                           0.989811
#
#                           FOXA1:AR(Forkhead,NR)/LNCAP-AR-ChIP-Seq(GSE27824)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           FOXA1:AR(Forkhead,NR)/LNCAP-AR-ChIP-Seq(GSE27824)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           FOXA1:AR(Forkhead,NR)/LNCAP-AR-ChIP-Seq(GSE27824)/Homer|conc  \
# chrm start     end
# chr1 100048200 100048700                                           0.636163
#      100048250 100048750                                           0.636163
#      100048300 100048800                                           0.636163
#      100048350 100048850                                           0.636163
#      100048400 100048900                                           0.636163
#
#                           Arnt:Ahr(bHLH)/MCF7-Arnt-ChIP-Seq(Lo_et_al.)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           ...  \
# chrm start     end        ...
# chr1 100048200 100048700  ...
#      100048250 100048750  ...
#      100048300 100048800  ...
#      100048350 100048850  ...
#      100048400 100048900  ...
#
#                           ZNF768(Zf)/Rajj-ZNF768-ChIP-Seq(GSE111879)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           ZNF768(Zf)/Rajj-ZNF768-ChIP-Seq(GSE111879)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           ZNF768(Zf)/Rajj-ZNF768-ChIP-Seq(GSE111879)/Homer|conc  \
# chrm start     end
# chr1 100048200 100048700                                           0.965006
#      100048250 100048750                                           0.965006
#      100048300 100048800                                           0.965006
#      100048350 100048850                                           0.965006
#      100048400 100048900                                           0.965006
#
#                           ZNF7(Zf)/HepG2-ZNF7.Flag-ChIP-Seq(Encode)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           ZNF7(Zf)/HepG2-ZNF7.Flag-ChIP-Seq(Encode)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           ZNF7(Zf)/HepG2-ZNF7.Flag-ChIP-Seq(Encode)/Homer|conc  \
# chrm start     end
# chr1 100048200 100048700                                           0.728655
#      100048250 100048750                                           0.728655
#      100048300 100048800                                           0.728655
#      100048350 100048850                                           0.728655
#      100048400 100048900                                           0.728655
#
#                           ZSCAN22(Zf)/HEK293-ZSCAN22.GFP-ChIP-Seq(GSE58341)/Homer|+  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           ZSCAN22(Zf)/HEK293-ZSCAN22.GFP-ChIP-Seq(GSE58341)/Homer|-  \
# chrm start     end
# chr1 100048200 100048700                                                0.0
#      100048250 100048750                                                0.0
#      100048300 100048800                                                0.0
#      100048350 100048850                                                0.0
#      100048400 100048900                                                0.0
#
#                           ZSCAN22(Zf)/HEK293-ZSCAN22.GFP-ChIP-Seq(GSE58341)/Homer|conc  \
# chrm start     end
# chr1 100048200 100048700                                           0.745794
#      100048250 100048750                                           0.745794
#      100048300 100048800                                           0.745794
#      100048350 100048850                                           0.745794
#      100048400 100048900                                           0.745794
#
#                           activity
# chrm start     end
# chr1 100048200 100048700  0.547170
#      100048250 100048750  0.696721
#      100048300 100048800  0.786378
#      100048350 100048850  0.750000
#      100048400 100048900  0.698876
#
# [5 rows x 1042 columns]

# %% [markdown]
# # groupby their columns

# %%
import re

# %%
def grouping_function(index_val):
    pattern = re.compile("(.+)\|.+")
    index_match = re.match(pattern, index_val).group(1)
    return index_match

# %%
def aggregate_function(cols):
    return cols.iloc[:, [0,1]].max(axis=1).multiply(cols.iloc[:, 2])

# %%
fadf = final_activity_df.iloc[:, :-1].groupby(final_activity_df.columns[:-1].map(grouping_function), axis=1).agg(aggregate_function)

# %%
fadf.shape
# Out:
# (1893193, 347)

# %%
fadf["activity"] = final_activity_df["activity"]

# %%
fadf.reset_index().to_csv(os.path.join(os.path.dirname(motif_df_path), "activity_data.csv.gz"), index=False)
